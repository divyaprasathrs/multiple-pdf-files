# %%
import pdfplumber
import os

def extract_text_from_folder(folder_path):
    
    pdf_texts = {}

    
    for filename in os.listdir(folder_path):
        if filename.lower().endswith(".pdf"): 
            pdf_path = os.path.join(folder_path, filename)
            with pdfplumber.open(pdf_path) as pdf:
                text = ""
                for page in pdf.pages:
                    text += page.extract_text() + "\n"
            pdf_texts[filename] = text  

    return pdf_texts

folder_path = r"C:\Users\Divya_prasath\Desktop\task\Sample_resume"

pdf_texts = extract_text_from_folder(folder_path)

for filename, text in pdf_texts.items():
    print(f"--- Text from {filename} ---\n{text}\n{'='*50}\n")
# Out:
# --- Text from Naukri_AJITHAV[2y_6m].pdf ---
# AJITHA V
# Professional Experience
# PYTHON DEVELOPER
# programmer analyst-ADM DEVELOPERS
# ajithavr99@gmail.com Dec 2021 – present
# 7010853283 Connecting applications to specific online applications and
# •
# services from third parties.
# Coimbatore,Tamilnadu
# Fixing bugs and making improvements to Computer programmes
# •
# and systems.
# Examining client requests and implementing required technical
# •
# Profile improvements.
# Examining client requests and implementing required technical
# •
# Have 1+ year of expertise in improvements.
# python development and be Analysis of data storage and incorporating them into various
# •
# effective at prioritizing many applications.
# tasks with a positive attitude.
# willingness to accept further
# obligations to achieve team Roles and responsibilities
# objectives.
# Assessing the needs of the application by coordinating with
# •
# development teams.
# Education
# Using Python to create scalable code
# •
# A programming language.
# Bachelor of science •
# Testing and application bug-fixing.
# •
# TNAU
# Creating components for the back end.
# •
# Madurai, India Using user-facing components to integrate logic on the server.
# •
# Evaluating and giving priority to client features requests .
# •
# Skills
# projects
# Python
# Stockflow
# Flask This project aims to monitor inventory levels, sales data, and invoice
# details for wholesale shops or suppliers. The system utilizes AWS S3
# HTML,CSS,Bootstrap
# as an AWS Bucket to optimize data processing and ensure precise
# inventory tracking and invoice generation. Flask, a backend
# MY SQL, SQL Alchemy
# framework, enables seamless data exchange between users and the
# system for efficient inventory control. Python programming
# Django
# language, along with Boto3 library, is used to interact with AWS
# Numpy services, including AWS S3, for uploading, updating, and retrieving
# invoices. The project employs the Pandas library to manipulate and
# Pandas process data related to inventory control effectively.
# RestAPI
# Git/Github
# PERSONAL INFORMATION
# FATHER NAME: K.Vellaichamy
# Languages
# ADDRESS: 14/1,3rd cross street,
# Thondi road, Sivaganga 630561
# Tamil
# English
#
# ==================================================
#
# --- Text from Naukri_ANISRAJ[2y_3m].pdf ---
# ANISRAJ.G
# 8526113766
# PYTHON DEVELOPER anisraj103@gmail.com
# PROFILE SUMMARY
# As a Python developer, I have 2yrs of experience of writing and reviewing high-quality code to client requirements. I thrive
# on learning new technologies, frameworks and the latest advancements in the field. My approach involves continuous
# research to identify and implement innovative and efficient coding solutions
# ORGANIZATIONAL EXPERIENCE
# Organization Duration Location Role
# Relentless systems July 2022 to present. Bangalore Software engineer
# A leading software development company in providing expert IT solutions to its global clients, focusing on enterprise
# solutions, and e-commerce solutions. My contribution is to Develop and review Python code for new application features,
# identified and debugged critical issues, contributing to a reduction in system errors and improving application stability
# ASSIGNMENT HIGHLIGHTS
# Execute Django application scripts, prepare and manage developed data
# Title GenoEncrypt
# Tools: MYSQL for reliable data storage. HashiCorp Vault for key management and OAuth 2.0 for secure
# authentication. For scalability and monitoring, tools like Redis and Prometheus are used to handle
# large volumes of genetic data and system performance tracking.
# Brief: Developed GenoEncrypt, a secure system for transmitting genetic data, by implementing advanced
# encryption protocols to safeguard information during transit. Integrated biometric authentication to
# enhance security and ensure user verification. Designed real-time monitoring features to track data
# integrity and ensure compliance with data protection regulations. Utilized JavaScript, ReactJS, and
# Python to build a robust, reliable, and compliant data transmission platform. This project significantly
# enhanced the security of sensitive genetic information and streamlined data handling processes.
# Role: (Backend): Develop secure APIs and communication channels using Django Channels to ensure data
# integrity during transmission. (Frontend): Build an intuitive interface with secure, real-time communication
# using ReactJS and WebSockets.
# Design the architecture to ensure encrypted, real-time secure transmission of genetic data. Implement
# cutting-edge encryption algorithms to protect sensitive genetic information during transmission.
# Continuously monitor data transmissions for unauthorized access and mitigate any security threats.
# Ensure compliance with data protection regulations like GDPR and HIPAA, particularly in securing
# genetic data.
# Title: GenoLegit
# Tools: MYSQL for reliable and scalable data storage. Implementing OAuth 2.0 and Auth0 will ensure robust
# authentication and authorization, while HashiCorp Vault guarantees secure encryption and key
# management. For compliance and monitoring, tools like OneTrust and ELK Stack are ideal for audit
# trails and regulatory adherence
# Brief: Project is designed to ensure that the handling of sensitive genetic data adheres to regulatory
# standards and ethical guidelines. The project focuses on compliance with global data protection laws
# ensuring the secure and lawful management of genetic information. A key aspect is the
# implementation of consent management systems, ensuring that user consent is obtained and verified
# before any access to genetic data.
# Role: Build user interfaces that ensure effective consent management and ethical access to genetic data
# using ReactJS.
# Implement encryption and access controls in the database to safeguard genetic data and ensure
# regulatory compliance.
# Establish and maintain detailed audit trails to monitor data access and manage compliance with
# data protection regulations.Provide ongoing system support to ensure reliability, address any issues,
# and report progress and resolution status to management.
# 1 of 2
# SKILLS
# • Skilled in functional software development using Python with a solid understanding of (OOP) concepts.
# • Proficient in web development using advanced tools in Flask and Django frameworks.
# • Strong understanding of MySQL for database management and backend development.
# • Experienced in frontend web development with a strong focus on React and JSX.
# • Solid knowledge of AWS for cloud deployment and services.
# • Experienced in software verification, validation processes, and authentication mechanisms.
# • Familiar with Agile methodologies for effective project management and development cycles.
# • Proficient in working with data analysis libraries such as NumPy and Pandas.
# • Extensive experience in API development, including Middleware, REST APIs, and REST frameworks
# TECHNICAL COMPETENCY
# Languages: Python, ReactJS
# IDE: VS code
# Database: My SQL
# Development Framework: Flask, Django
# Management Tool: Git, Celery, Hashicorp vault
# Others tool: Docker, Kubernetes
# Domain: Python development
# EDUCATION
# Degree College/University Year
# Bachelor of Engineering [ME] Anna University, Tamil nadu 2019
# LANGUAGES
# • Tamil(native)
# • English
# PERSONAL DETAILS
# Sex: Male
# D.O.B: 7th Jun 1998
# Nationality: Indian
# Present Address: No-2/13A, chinnamelupalli, Krishnagiri.
# STRENGTHS
# • Creative thinker
# • Strong problem-solving skills
# • Good team player with a strong work ethic
# • Committed to completing tasks
# INTERESTS
# • Football
# • Cycling/trekking
# 2 of 2
#
# ==================================================
#
# --- Text from Naukri_AnushaB[1y_1m].pdf ---
# ANUSHA B
# Contact No: +91 9677495546
# Email Id: anushabt00@gmail.com
# LinkedIn: https://www.linkedin.com/in/anusha-b-331278227
# Career Objective
# Motivated recruiter with 1 year of full-cycle recruitment experience, adept at sourcing, screening, and
# building relationships. Dedicated to delivering top talent aligned with company goals, improving
# recruitment strategies, and ensuring positive candidate experiences.
# Profile Summary
#  Having 1 year of work experience in Complete Recruitment.
#  Practical experience throughout the entire recruitment process, encompassing sourcing,
# screening, shortlisting, scheduling, follow-up, and overseeing candidate onboarding.
#  Capable of effectively recruiting candidates across all career levels, from junior to senior
# positions.
#  Having experience in recruiting people across both service and product based.
#  Experience in recruiting for IT, Automotive, Banking, Telecom, Healthcare, and Insurance
# sectors.
#  Possess excellent communications and interpersonal skills.
# Professional Summary:
# Organization: Canvendor Software Solutions
# Role: IT/Technical Recruiter.
# Duration: July 2023 to Till Date.
# Roles & Responsibilities
#  Full Expertise in Permanent and C2H Hiring
#  Successfully recruited across a broad spectrum of IT and Automotive specialties, spanning
# junior, senior, middle, and executive management levels, including niche requirements.
#  Good technical knowledge and Fast Learning ability to understand new technologies.
#  Expertise in the areas of sourcing, screening, validating, interview coordination.
#  Demonstrated proficiency in utilizing job portals such as Naukri and LinkedIn, as well as
# leveraging referrals and social networks.
#  Develop, influence, and execute sourcing strategy for passive and active candidates.
#  Technically screen candidates for their technical skills as per the requirements.
#  Following up with prospective candidates until they complete all rounds of the interview.
#  Follow ups with the candidates regarding acceptance of offer, joining dates and ensure the
# candidates join the organization.
# Requirements / positions worked: Design Engineers (Automotive), ADAS Developer, Python
# Automation, Automation Engineers, Infotainment engineers, Technical Writer, Test Engineers, Java .NET,
# PHP, Network Engineer, Data analyst, System Engineer, IT Manger, Project Manager, DevOps, Business
# Analyst, Big Data, Data Engineer, Manual & Automation Testing, SAP, ETL, iOS, Android, Mainframe etc
# Domains:
#  IT Services, Automotive, Banking, Manufacturing, Telecom, Healthcare, Insurance etc.
# KEY SKILLS
#  Full-cycle recruitment: Handling sourcing, shortlisting, scheduling, documentation, and
# background verification.
#  HR discussions, offer management, and onboarding.
#  Collaborating with hiring managers to understand specific skill profiles needed.
#  Screening candidates from job portals (Naukri, LinkedIn) based on experience and role fit.
#  Identifying and selecting candidates with the right skills and experience for lateral hiring.
#  Conducting HR rounds, negotiating salaries, and providing feedback to candidates.
#  Ensuring compliance with background verification policies.
#  Proficient in MS Word, Excel, and PowerPoint presentations.
# Academic Qualification:
#  MBA – HR and Finance from Amrita College of Engineering and Technology -2022 with 8.5 CGPA
#  B.com –S.T. Hindu College – 2020 with 8 CGPA
#  Higher Secondary – S. M. R. V. Higher Secondary School - 2017 with 96%
#  SSLC – Govt. Higher Secondary School - 2015 with 90%
# Strengths and Areas of Interest:
#  Resilient and motivated to contribute and succeed.
#  Maintains focus and performs well under pressure.
#  Works well with team members.
#  Eager to learn and adapt to new technologies quickly.
# PERSONAL DOSSIER
# Date of Birth: 02-Oct-2000
# Sex Male
# Marital Status: Unmarried
# Nationality: Indian
# Present Address: 20-15/1, South St,
# Kurathiyarai, Azhagiapandiapuram PO,
# Kanyakumari Dist,
# Tamilnadu – 629851
# Declaration:
# I hereby certify that the above information is true and correct to the best of my knowledge and belief.
# Date: Anusha B
#
# ==================================================
#
# --- Text from Naukri_ArulMozhiVarmanS[5y_6m].pdf ---
# Arul Mozhi Varman
# Chennai
# (+91) 8508932314 arulmozhivarman861@gmail.com
# PROFESSIONAL SUMMARY
# Experienced Linux System Administrator with over 5 years of hands-on expertise in managing,
# configuring, and optimizing Linux systems in production environments. Skilled in installing,
# configuring, and maintaining Linux servers (Red Hat, CentOS, Ubuntu) and administering various
# services like Apache, Nginx, MySQL, and SSH. Proven track record of implementing robust security
# measures, patch management, and system hardening following industry best practices
# SKILLS
# ● Operating Systems: Red Hat Enterprise Linux, ● Security: OpenSSH, TCP wrappers, iptables,
# Centos, Ubuntu, SUSE. firewalld, SELinux.
# ● Linux utilities: LVM, fdisk, parted, SCP, ftp, zip, ● Virtualization: VMware ESXi, vSphere, Center.
# tar. ● Cloud Tools: AWS, Microsoft Azure
# ● Monitoring & Scan Tools: Zabbix, Nagios,
# CloudWatch.
# ● Network Tools: Telnet, Traceroute, Ping, Dig,
# Netstat, Nslookup etc.
# WORK HISTORY
# SENIOR LINUX ADMINISTRATOR |04/2022 - Current
# Concentrix -Chennai, India
# ● Systems administration, maintenance and monitoring of various day-to-day operations.
# ● Providing Full-Fledged support over 24/7 on Unix/Linux Servers.
# ● Responsible for managing more than 2500 LINUX servers through virtualization and including
# physical server and cloud server(AWS)
# ● Managed the disaster recovery activity.
# ● We manage the application server like Oracle Database, Sybase, Hadoop, and Oracle EBS.
# ● Installation, Configuration, and OS patches on RHEL, SUSE Linux.
# ● Creating volume groups, Logical volumes and extending them using LVM.
# ● Package Management using RPM, YUM and ZYPPER.
# User Management: User/Group creation, deletion, password reset, unlock.
# ● Diagnosing, monitoring performance and network related issues using PS, top, netstat.
# ● Handling server hung, unplanned reboots and filling up RCA for complex issues.
# ● Performs incident management and change management execution.
# ● Collaborate with Infrastructure, Development and QA to resolve production issues.
# ● File system management (including files and folder permissions, special permissions, ACL).
# ● Performing system administration activities including installation and troubleshooting.
# ● Troubleshooting issues with live production Linux servers.
# Checking log files and answering technical queries of end user.
# ● Planning and resolving the issues within the specified down time.
# ● Automation of jobs through crontab.
# ● Daemon and process management (starting, stopping and refreshing).
# ● Work on tickets assigned and ensure tickets meet SLA metrics.
# ● Managed Disks and File systems using LVM on Linux.
# Taking Full Responsibility & Ownership of all OS-related issues.
# ● Applied appropriate support packages/patches to maintain system integrity.
# ● Good Knowledge in checking the log and troubleshooting the issues according to the issue.
# ● Providing day-to-day user administration like adding or deleting users, and password aging.
# Monitoring the Infrastructure using the below list of tools like VictorOps, Control-M, AWS, GRID,
# Jira, NewRelic, and Slack within an SLA.
# ● Monitoring and Scheduling in the Control-M tool where all production jobs execting it.
# ● Patching the server (Both Manual & Automation via Blade Logic tool) & Firmware upgrades for
# the servers
# Using the service now ticketing tool to create an alert suppression, incident, change request
# and problem management.
# ● Using the DBArmor tool for reporting purposes, sending a communication to stakeholders, to
# update the status of the server.
# ● Using DB squad tool to get the information about the server (i.e without login the server you can
# get fetch some command output using the time machine).
# ● Using the Cyber-Ark tool for the root password and console password by creating the request to
# the cyber arc team with proper approval.
# SYSTEM ENGINEER |11/2016 - 07/2020
# Oramate Technology -Chennai, India
# ● Systems administration, maintenance and monitoring of various day-to-day operations
# ● Providing Full-Fledged support over 24/7 on Unix/Linux Servers
# ● Planning and implementing system upgrades including hardware, operating system and
# periodical patch upgrades
# ● Enterprise Level experience in Production Environment
# ● Handling issues pertaining to FTP, Printing, File System administration, Server performance,
# Backups and restorations, troubleshooting
# ● Remote System administration skills using ILOM, console
# ● Upgrading system kernel version to the latest using YUM utility and maintain GRUB configuration
# ● Configuring SSH keys for the Password less authentication between two users
# ● Working with Red Hat vendor and sharing sosreport while resolving any LVM issues
# ● Knowledge of ITIL framework/methodology
# ● Storage / backup operations experience at host/client side
# ● Performing the tasks like HW Replacement (HBA/Disk/Memory/CPU/Full system) with vendors
# ● Pushing WWN after the HBA Replacement
# ● Performing the memory checks and clearing the old logs and performing checkouts on the host
# after replacing the Faulty Memory by Hardware team
# ● Interacting with customers and end-users to resolve their queries in a timely and accurate
# manner
# ● Performing offline Diagnostics based on HP Vendor suggestions
# ● Performing the role of Incident Management and Handling issues like Handling when there is
# Flood of alerts and joining the Bridge calls and making sure the issues get resolved within the
# preferred SLA
# ● Performing the Job Automation
# ● RAID Levels (like raid0, raid1, raid5) configurations
# ● Installation of Red Hat Linux and configuration
# ● Setting up YUM server, Configuration & Installation of rpm packages, Configuration of RAID, LVM
# layout, ILO configuration for physical servers
# ● Knowledge about TCP/IP
# ● VMware Exposure on Compaq ProLiant DL 380 server's board
# ● Creating and managing virtual guest machines, tools installation
# ● Virtual Machine capacity management & vSphere Client Software Exposure
# ● Install & configure Operating Systems: RHEL5 RHEL6 ESX, ESXi, VMware vSphereVmstat, SAR,
# iostat, top
# ● Installation of rpm packages, Configuration of RAID, LVM layout
# ● ILO configuration for physical servers
# ● Extensive working experience with Linux, IPTable Rules
# ● Experience of Linux (RHEL), (trouble shoot, installing, performance tuning
# ● Configuration and hardening of Linux (RHEL) as per the organization standards
# ● Responsible for day-to-day operational maintenance, support, OS installations and upgrades for
# enterprise servers
# ● File system Creation/Management/Administration, e.g
# ● Logical Volume Management, Creating symlinks, changing permissions, setting persistent
# Mounts etc
# ● Analyzing the issue if require a down time coordinate with other team to arrange downtime
# ● Snapshot management
# ● Perform capacity analysis, monitor, and control disk space usage on systems
# ● Monitor system activities and fine tune system parameters and configurations to optimize
# performance and ensure security of systems
# ● Setting up network environments using TCP/IP, NFS, DNS, DHCP and FTP
# ● Set up user and group login ID's, printing parameters, network configuration, password, resolving
# permissions issues, user and group quota
# ● Good Knowledge in checking the log and troubleshooting the issues according to the issue
# ● Providing day-to-day user administration like adding or deleting users, password aging
# ● Patching the server (Both Manual & Automation via Blade Logic tool) & Firmware upgrades for
# the servers.
# EDUCATION
# Anna University -Chennai, India |B.Tech/B.E.
# 07/2011 - 04/2015- Merit
# PERSONAL DETAILS
# ● Father's Name: Selvakumar
# ● Title: Senior Linux Administrator
# ● Date of birth: 06/08/1994
# ● Gender: Male
# ● Nationality: Indian
# ● Martial Status: Single
# ● Language: English, Tamil
# ● Current Location: Chennai
# ● Preferred Location: Chennai, Bangalore, Coimbatore.
#
# ==================================================
#
# --- Text from Naukri_AshwiniNatesan[7y_0m] 1.pdf ---
# ASHWINI NATESAN
# Project Manager | Scrum Master | Agile Coach
# +91 90942 50130 @ ashwininatesan1317@gmail.com
# https://www.linkedin.com/in/ashwini-natesan Q Chennai, Tamilnadu
# SUMMARY ACHIEVEMENTS
# Experienced Project Management Professional with 7 years of expertise. Project Management
# Proven track record in delivering quality results, adhering to timelines and
# budgets. Seeking challenging roles to leverage project management skills
# Successfully led a cross-functional team
# and Agile practices for success. Skilled in team leadership and driving through the end-to-end delivery of a critical
# project, meeting all milestones and
# organizational goals.
# achieving project objectives within allocated
# time and budget constraints.
# EXPERIENCE
# Vue.js Development
# Project Manager
# Spearheaded the development and
# PHOTON implementation of innovative features in
# 01/2020 - Present Chennai, Tamilnadu Vue.js, enhancing user interface
# Managed the entire e-Form project from start to finish, including responsiveness and elevating overall user
# development, implementation and maintenance. experience, resulting in increased user
# Worked closely with L'Oréal stakeholders to gather requirements, ensure engagement and satisfaction metrics
# alignment with business objectives.
# Identified potential risks associated with handling sensitive information Scrum Master
# and implemented robust risk mitigation strategies.
# Used Agile methods to enable flexible development cycles, responding to Guiding the team in achieving consistent
# sprint goals, fostering a culture of
# changing requirements.
# continuous improvement, and ensuring
# Led and guided the project team to deliver high-quality solutions on time project delivery ahead of schedule with high
# and within budget.
# quality standards
# Ensured compliance with data protection regulations and industry
# standards for the e-Form application.
# SKILLS
# Software Developer
# Agile Confluence Scrum Kanban
# TIMEMIN SOLUTIONS
# 05/2017 - 10/2019 Chennai, Tamilnadu
# Helped design and develop iOS and Android apps for smooth user PMP VueJS PMBOK Node G it
# experiences.
# Managed SVN repository and Vue.js frameworks for version control and Stakeholder Engagement Leadership
# frontend development.
# Worked on multilingual shopping websites, focusing on core features and
# Risk Management JavaScript
# user support.
# Used Vue and SVN for frontend development and version control,
# integrating payment features with Hyperpay. Budgeting Agile tools (JIRA, Trello)
# Collaborated with Angular developers to integrate Vue.js and Angular
# components.
# Shared knowledge and collaborated with team members for growth and COURSES
# development.
# Scrum Master Certification
# EDUCATION Completed comprehensive training in Scrum
# methodologies, mastering techniques for
# facilitating Agile development processes, sprint
# B.Tech in Information Technology
# planning, and team collaboration to drive project
# SKR Engineering College, Anna University success
# 01/2014 - 01/2018 Chennai, Tamilnadu
# Project Management Professional (PMP)
# Certification
# LANGUAGES
# Completed training in project management,
# showing expertise in planning, execution,
# English Tamil
# stakeholder management, risk assessment, and
# Advanced Native
# quality assurance
#
# ==================================================
#
# --- Text from Naukri_AthiraU[5y_4m].pdf ---
# ATHIRA U
# Certified Scrum Master targeting mid/senior level assignments in with an organization of high
# repute in IT Industry
# Ph: +91-9746226373 Email: athirauday05@gmail.com
# rathifreshers@gmail.com
# Profile Summary
# As a Certified Scrum Master with 5+ years of experience in software delivery, I am an enthusiastic team coach and
# action-oriented leader. My expertise in Agile processes and Scrum Master role experience of 2 years has enabled me to
# successfully lead teams through complex software development cycles using Agile methodologies.
# Here are some of my accomplishments and skills:
# • An accomplished B.Tech graduate in Electronic and Communication with 5+ years of experience.
# • Led teams in sprint planning, daily stand-ups, sprint reviews, and retrospectives using the Scrum framework to
# ensure timely delivery of high-quality products, with 3 years in agile environments
# • Applied widely successful Agile techniques, including User Stories, Continuous Integration, Continuous
# Testing, Paired Programming, and Agile Games; demonstrated deep subject knowledge in backlog management,
# scrum ceremonies, DOR, DOD, Acceptance Criteria, Estimation, Story Splitting, and adept JIRA board management.
# • Communicated effectively with stakeholders, keeping them informed and engaged throughout the project
# lifecycle, leading to increased stakeholder satisfaction and successful project delivery.
# • Relentlessly focused on removing impediments for teams, ensuring that team members have what they need
# to deliver high-quality products.
# • Passionate about continuous improvement, I implement best practices to promote productivity, efficiency, and
# high-quality deliverables, leading to improved team performance and stakeholder satisfaction.
# • Committed to helping teams achieve their full potential, I provide coaching and guidance to team
# members to help them grow, leading to a more engaged and motivated team that delivers results that exceed
# customer expectations.
# Core Competencies
# Servant Leadership Stake Holder Communication Agile Trainings
# Team Building & Management F a c i l i t a t i o n T e c h n i q u e s C o a c h i ng
# Knowledge Purview
# • Agile, Scrum & Kanban & SAFe
# • JIRA & Confluence
# • MS Office tools
# Professional Certifications
# Certification Name Certification Name
# ✓ Certified SAFe® 6 Scrum Master ✓ Kickoff Certification - PMI
# ✓ Professional Scrum Master I ✓ Agile Certification - JP Morgan
# ✓ JIRA Certification ✓ Agile Certification - Cognizant
# ✓ Trello Certification ✓ Scrum Foundation Certification
# ✓ Confluence Certification ✓ Design Thinking Certification - IBM
# ✓ Basic of Scrum Certification – PMI ✓ Generative AI Overview for Project Managers – PMI
# Work Experience
# Mitel from May 2023 – Present
# Key Result Areas:
# As a Scrum Master
# • Successfully led Scrum teams through all phases of software development lifecycle, ensuring timely delivery of
# high-quality products while facilitating efficient and effective Scrum ceremonies.
# • Facilitated communication and collaboration between offshore and onshore teams, ensuring efficient
# project delivery and alignment on project goals and objectives.
# • Fostering a culture of continuous improvement and learning, I coached team members in Agile practices,
# resulting in an increase in team satisfaction.
# • Proactively identified and communicated risks and issues to project stakeholders while working with the team
# to develop solutions and mitigate risks, resulting in successful project delivery.
# • Conducted fun team-building events, resulting in increased comfort and transparency among team members at
# all levels of product development.
# • Streamlined Sprint planning and release planning meetings by collaborating with the team to break down
# feature stories into small, deliverable user stories that are appropriately sized for each Sprint.
# • Enabled improvement in team delivery commitments and capacity planning for Sprints by identifying and
# tracking hidden tasks that increased customer satisfaction, while also coaching the team with the Product Owner in
# understanding the vision and goals of the project with each Sprint in focus.
# • Facilitated test execution coordination, established weekly priorities, tracked progress, and ensured resource
# availability for the team in an agile environment.
# • Tracked team productivity, provided functional support and training to new members, and established QA policies
# and procedures including documentation for stakeholders.
# Previous roles:
# MOVATE from Sep 2022 to May 2023 As a Team Leader
# Bharti Airtel from March 2021 to Sep 2022 As an agile Team Member
# The Unique Culture from May 2019 to Feb 2021 as an agile team member
# Key Roles:
# • Delivered customer-focused solutions by actively engaging in customer feedback loops, aligning service delivery with
# evolving B2B requirements through iterative design, testing, and provisioning.
# • Executed network optimizations by implementing planned network changes, including traffic shifts and bandwidth
# adjustments, ensuring continuous delivery and minimal disruption.
# • Performed circuit validation and optimization by analyzing routes to reduce latency and prevent disruptions, applying
# Agile principles to continuously improve routing strategies.
# • Maintained system integrity by updating and managing the Inventory Management System, ensuring accurate and
# reliable data across customer records using tools like Metasolv (M6).
# • Collaborated in cross-functional teams to analyze and enhance SIP voice traffic efficiency, utilizing tools like Wireshark
# to drive continuous improvements in VoIP network performance.
# Education
# • B.E Electronics and Communication Engineering
# Personal Details
# Hobbies: Dancing & Hardware assembling
# Languages Known: Tamil, Malayalam, Hindi and English
#
#
# ==================================================
#
# --- Text from Naukri_AzarudeenA[3y_0m].pdf ---
# Azarudeen A
# Tiruchirappalli, Tamilnadu
# 9360047121 | azarudeensuban@gmail.com
# Objective
# To work in an environment which encourages me to succeed and grow professionally where I can utilize my skills and knowledge
# appropriately.
# Experience
# T4TEQ Software Solutions Jun 2022 - Jun 2023
# Web Developer
# •Proficient in developing and managing web applications using Django, Python, and RESTful APIs, ensuring seamless functionality and
# scalability.
# •Skilled in front-end technologies including HTML, CSS, JavaScript, and frameworks like Bootstrap, enabling responsive and user-friendly
# design.
# •Experienced with database management using PostgreSQL and MySQL, including writing efficient queries and optimizing performance.
# •Solid understanding of backend workflows, authentication mechanisms, and MVT architecture, ensuring robust application development.
# •Strong foundation in algorithms and data structures, with practical experience in arrays, linked lists, and problem-solving for optimal code
# design.
# Electrowing Technologies Dec 2023 - Mar 2024
# Software Design Engineer
# •Developed applications for the Indian defense domain, contributing to critical government projects, including the CEMILAC defense
# initiative.
# •Enhanced proficiency in advanced C++ and Qt for desktop application development, ensuring high-quality and efficient software
# solutions.
# •Designed and implemented logic for various application modules, including data plotting and small-scale functionalities.
# •Gained foundational knowledge of the embedded domain, understanding how code interacts with electronic devices.
# •Delivered reliable and secure software solutions, adhering to stringent requirements for defense applications.
# Vinsup Infotech Apr 2024 - Present
# Python Trainer
# •Design and assign creative programming tasks to help students enhance their problem-solving skills and improve algorithmic thinking.
# •Develop comprehensive programming manuals for languages like C, Java, and Python, making learning more accessible and tracking
# student progress effectively.
# •Build expertise in API development using Django and Flask, while integrating front-end technologies with back-end frameworks like React
# and Django.
# •Continuously expand intermediate-level Python skills with a focus on practical application and project development.
# •Train students in advanced Python concepts and libraries, providing in-depth knowledge and hands-on experience to prepare them for
# real-world challenges.
# Education
# Bishop Heber College 2022
# B.Sc Computer Science
# 7.74
# Skills
# C
# Python
# Flask
# Django
# React
# SQL
# HTML
# CSS
# JavaScript
# RESTful APIs
# Git
# Problem solving
# Communication
# Projects
# Roomxpense
# A Django-based application designed for managing shared group expenses like rent, utilities, and groceries. It automates expense
# distribution, tracks payments, and calculates settlements, ensuring accurate and hassle-free financial management for roommates or
# group scenarios.
# Academy Management System
# A Django-based application developed to manage academic operations and billing processes efficiently. Features include student
# registration, course management, attendance tracking, and automated fee billing with invoice generation. The system streamlines
# administrative tasks and ensures accurate financial records for educational institutions.
# Certifications
# CS50's Introduction to Programming with Python (CS50P): Earned certification from Harvard University for completing this foundational
# course, covering Python programming concepts, data structures, and problem-solving techniques.
# CS50's Introduction to Programming with Python (CS50P): Earned certification from Harvard University for completing this foundational
# course, covering Python programming concepts, data structures, and problem-solving techniques.
# Programming in Python
# Programming in C
# JavaScript Intermediate
#
# ==================================================
#
# --- Text from Naukri_Balajee[14y_0m].pdf ---
# Balajee
# Cell: +91-7901533189
# Email: nagabalajifmw@gmail.com
# Balajee
# Platform administration Consultant
# Contact: +91-7901533189
# Summary:
# ✓ Platform administration in 14.0 years of experience in the area of on AWS, Azure, Google
# cloud and DEVOPS, Linux, RHEL. Oracle Fusion Middleware, WebLogic, SOA, OIC, Web
# Servers, and Middleware production support.
# ✓ Implementation Fusion Middleware products 11g and 12c such as WebLogic server, SOA suite,
# Oracle forms and reports, OBIEE and SOA Cloud services.
# ✓ Knowledge on Oracle SOA CLOUD SERVICE.
# ✓ Creating Domain on multiple host Environment. Experience in Architecture and Installation,
# Patching, Oracle Databases.
# ✓ Monitoring Database alert logs and trace files for errors.
# ✓ Good working experience in Installation, Configuration, Performance Tuning and Trouble
# Shooting of WebLogic Versions 9.x/10.x (11g and 12c).
# ✓ SSL Certificate Configuration on WebLogic and middleware products
# ✓ Expert knowledge and hands on experience of SOA, ESB, OHS.
# ✓ Creating Schemas using Repository Creation Utility - RCU
# ✓ Experience in configuration, Administration and Tuning of Middleware Components
# ✓ Deployment/Configuring Forms and Reports, Troubleshooting Issues
# ✓ Providing On-Call Production Support as per rotation basis
# ✓ Understanding of Unix Shell Scripting language, Python, WLST scripting
# ✓ Familiarity with ITIL concepts and best practices.
# ✓ Strong analytical, Troubleshooting and Investigation skills.
# ✓ Performing Oracle Applications Utilities like AD Administration, AD Controller, Autoconfig, AD
# Relink and Auto Patch, f60gen, and managed passwords by using FNDCPASS.
# Balajee
# Cell: +91-7901533189
# Email: nagabalajifmw@gmail.com
# ✓ Managing and Monitoring the JVM Performance by adjusting WebLogic heap size and garbage
# collection parameters
# ✓ Good working experience in Installation, Configuration, Performance Tuning and Trouble
# Shooting of SOA Environment (Service Engines, Adapters, BAM…).
# ✓ Install and configure Oracle SOA Suite 11g components in Oracle WebLogic Server domains.
# ✓ Implementation projects Oracle WebCenter Suite (Oracle WCC 12c, ADF UI, 11g and Oracle
# WCP) 12.2.1.4.0
# ✓ Monitor and manage SOA Components by using the Oracle Enterprise Manager Fusion
# Middleware Control Console to perform administrative tasks.
# ✓ Configuring, Deploying and Monitoring the SOA composite applications.
# ✓ Monitor and manage SOA Components by using the Oracle Enterprise Manager and Fusion
# Admin Console to perform administrative tasks.
# ✓ Troubleshoot SOA composite applications by performing corrective actions such as fault
# recovery.
# Programming and Software skills:
# Cloud AWS, Google, Azure, Oracle cloud services
# Application Servers Oracle WebLogic Server 11g & 12c
# Database Oracle Database 10g & 11g
# Fusion Middleware SOA, BAM, BPEL, JMS, LDAP
# SSO, OAM, ESB, OHS,
# Operating Systems Windows, UNIX, RHEL, Linux- OEL
# Web Server Apache HTTP Server.
# Oracle SOA/J2EE Technologies Servlets, JDBC, JSP, Hibernate and EJB, Oracle SOA Suite 10g &
# 11g, ADAPTORS, BAM.
# Languages J2EE, BPEL, XML, WSDL, XSD
# DBMS/RDBMS Oracle 10g, 11g
# Memory Profiling Tools Samurai.
# Certifications and Secondary skills:
# ✓ Architecting Solutions on AWS
# ✓ Migrating to the AWS Cloud
# ✓ AWS Cloud Technical Essentials
# ✓ Google Cloud Fundamentals: Core Infrastructure
# ✓ Introduction to DevOps
# ✓ Introduction to Microsoft Azure Cloud Services
# Balajee
# Cell: +91-7901533189
# Email: nagabalajifmw@gmail.com
# ✓ DevOps on AWS: Code, Build, and Test
# Education Qualification:
# B.Sc. (Bachelor of Science) Graduation from Andhra University, in 2002.
# Professional Experience:
# ➢ Working in BirlaSoft for HP client as full time since October 2022 to till February 2024.
# ➢ Worked in Data Intensity as permanent payroll.
# ➢ Worked in QNB-Qatar National Bank payroll of Aufait Technologies. WebCenter suite,
# WebCenter portal both .12.2.1.3.0).
# ➢ Worked in SURTEL TECHNOLOGIES as a permanent payroll, Indore Madhya Pradesh WebCenter
# suite, WebCenter portal both .12.2.1.3.0)
# ➢ Worked in ITC InfoTech. as Lead Consultant deputed to Oracle India.
# ➢ Worked in UST-GLOBAL INDIA PRIVATE LIMITED as a Systems Analyst in DELL, Bangalore.
# ➢ Worked in TRAVANT SYSTEMS PRIVATE LIMITED deputed to Bodh Tree technologies.
# Client details:
# ➢ Worked with HP Project from BirlaSoft.
# ➢ Data Intensity for various clients
# ➢ Qatar National Bank, Barwa Bank and Hamad Bin Khalifa University (HBKU).
# ➢ RSIFOCON united states through SURTEL TECHNOLOGIES.
# ➢ Worked in Oracle India Private Limited Hyderabad under the payroll of ITC InfoTech India Ltd.
# ➢ Worked in DELL Hyderabad, under the payroll of UST-GLOBAL INDIA PRIVATE LIMITED as
# Systems Analyst.
# ➢ Worked in Bodh tree under the payroll of TRAVANT SYSTEMS PRIVATE LIMITED.
# Balajee
# Cell: +91-7901533189
# Email: nagabalajifmw@gmail.com
# Project details:
# ➢ Worked as a senior technical lead for HP project from BirlaSoft.
# ➢ Worked as a Senior Fusion middleware consultant in Data Intensity
# ➢ As a Fusion middleware admin in Qatar National Bank, Barwa Bank and Hamad Bin Khalifa
# University (HBKU) QATAR.
# ➢ Worked as a senior software associate in Surtel Technologies, Indore Madhya Pradesh.
# ➢ INC Research clinical research organization and Tervis project in Oracle India Private Limited
# Hyderabad with the team size 10 members.
# ➢ Handled AMS-EMS-EUC project in DELL Hyderabad with the team size 20 members.
# ➢ Previously i handled the Igloo project in Bodh tree under the payroll of TRAVANT SYSTEMS
# PRIVATE LIMITED with the Team size of 10 members.
# Projects Overview:
# 1. HP Project
# Client: HP
# Role: Fusion middleware administrator
# ✓ Health check of prod and non-prod environments.
# ✓ Issue resolution if any abnormal behavior of the WebLogic servers.
# ✓ General report monitoring with respective servers.
# ✓ We coordinating with application teams and also providing the issue resolutions.
# ✓ Doing the deployments on PROD and non-Prod environments.
# ✓ Quarterly, half yearly, and yearly patching on respective domains.
# ✓ Application test connectivity for new integrations.
# ✓ Working the restart the services while do the db. servers patching either it is windows and
# Linux and coordinated with the db. and network teams.
# ✓ Monthly Metrix activities observing the transaction details.
# Balajee
# Cell: +91-7901533189
# Email: nagabalajifmw@gmail.com
# ✓ Worked on the incidents based on the priorities like service bus failure incidents which is
# related to user account password expired or space issues on those servers.
# 2. Qatar National Bank (QNB), Barwa Bank, and Hamad Bin Khalifa University (HBKU)
# Client: QNB, Barwa Bank, HBKU
# Role: Fusion middleware admin
# Environment:
# · Oracle WebLogic Server (12.2.1.3.0), SOA 11g & 12c (12.2.1.3.0.), Oracle Database, Linux flavors.
# ✓ Installation and configuration latest version of Fusion middleware products.
# ✓ Patching activity on PROD QA TEST for SOA environments.
# ✓ Monitoring web center sites and portal and admin activities for priority issues.
# ✓ Implementation project done with SOA suite from OS level (WebLogic and SOA).
# ✓ Bug fixes on Oracle forms and reports servers.
# ✓ Thread monitoring on WebLogic servers.
# ✓ SSL configuration on different domains.
# ✓ Involving with Service request related to high level critical impact.
# ✓ Deployments and data sources configuration for oracle web center sites.
# ✓ Oracle Web center sites performance.
# 3.Rsinfocon Implementation Project-
# Client: RSINFOCON.
# Role: Senior Associate.
# Environment:
# · Oracle WebLogic Server, SOA 11g & 12c (12.1.3.0.0), OEM 12c, Oracle Database, OEL Linux,
# Windows server 2012 R12.
# Balajee
# Cell: +91-7901533189
# Email: nagabalajifmw@gmail.com
# Responsibilities:
# ✓ Monitoring OSB environment reprocess the failed jobs OSB console.
# ✓ Implementation project done with SOA suite from OS WebLogic and SOA.
# ✓ DB adapter configuration JD Edwards.
# ✓ Oracle application adapter configuration.
# ✓ Monitor and manage SOA Components by using the Oracle Enterprise Manager Fusion
# Middleware Control Console to perform administrative tasks.
# ✓ Deploying SOA composite applications.
# ✓ Configuring SOA composite application resources.
# ✓ Monitoring SOA composite applications.
# ✓ Managing and monitoring service engines, and updating the state of SOA composite
# applications.
# ✓ Troubleshoot SOA composite applications by performing corrective actions such as fault
# recovery.
# ✓ Tuning and configuring Oracle SOA Suite 11g environment for high availability.
# ✓ Managing and Monitoring the JVM performance by WebLogic Heap Size, Garbage collection.
# ✓ Conversant with quality procedures, while executing projects and has good customer
# orientation.
# ✓ Provided 24/7 on call support for production. Installation and configuration of various
# middleware packages.
# 4. Inc. OMS research health care project
# Client: INC RESEARCH.
# Role : System lead.
# Environment:
# · Oracle WebLogic Server 11g (11.1.1.7.0) & 12c (12.1.3.0.0), OEM 12c, Oracle Database, OEL Linux,
# Windows server 2007.
# Balajee
# Cell: +91-7901533189
# Email: nagabalajifmw@gmail.com
# Responsibilities:
# ✓ Involved in Production Deployment on weekend
# ✓ Identifying and Resolving Production Issues.
# ✓ Importing and exporting for implementation
# ✓ Good Knowledge on SOA cloud services, IAAS, PAAS, SAAS
# ✓ Configuration of domains changes.
# ✓ Understanding Client code including EJB, JSP, Servlets, Struts, Web Services.
# ✓ Enhancing the current code to provide optimum flexibility.
# ✓ Developing and troubleshooting Web Services
# ✓ Using WebLogic Diagnostic Framework for Production Support and Archiving data.
# ✓ Installation and configuration of OHS Web Servers.
# ✓ Configuration and Administration of Web Servers and pointing the directives to appropriate
# WebLogic Servers.
# ✓ Taking training sessions to Junior.
# ✓ Participated in KT Sessions for NEW Managed Services Project
# ✓ Worked with clients to get the infrastructure requirements for implementing new projects and
# preparing roll-out schedules.
# ✓ Supporting application Performance Monitoring Team and production support, assist with
# UAT/Performance testing and DR Testing.
# ✓ Configured JDBC resources, data sources and bounded to the J2EE applications, configured the
# connection pools for the data sources.
# ✓ Estimation for new Releases, Initiatives and Work Requests
# 5. Internal AMS EMS Support project
# Client: Dell International
# Role: System Analyst
# Balajee
# Cell: +91-7901533189
# Email: nagabalajifmw@gmail.com
# Environment:
# · Oracle WebLogic Server 11g (11.1.1.7.0) & 12c (12.1.3.0.0), OEM 12c, Oracle Database, OEL Linux,
# Windows server 2012 R12.
# Responsibilities:
# ✓ Doing the application deployments JAR, EAR, WAR files.
# ✓ SSL configuration for DEV, QA environments.
# ✓ Monitor and manage SOA Components by using the Oracle Enterprise Manager Fusion
# Middleware Control Console to perform administrative tasks.
# ✓ Deploying SOA composite applications.
# ✓ Configuring SOA composite application resources.
# ✓ Monitoring SOA composite applications.
# ✓ Managing and monitoring service engines, and updating the state of SOA composite
# applications.
# ✓ Troubleshoot SOA composite applications by performing corrective actions such as fault
# recovery.
# ✓ Tuning and configuring Oracle SOA Suite 11g environment for high availability.
# ✓ Managing and Monitoring the JVM performance by WebLogic Heap Size, Garbage collection.
# ✓ Conversant with quality procedures, while executing projects and has good customer
# orientation.
# 6. Igloo Bodh tree support product
# Client: Igloo Logitech
# Role: WebLogic administrator
# Environment:
# · Oracle WebLogic Server 11g (11.1.1.7.0) & 12c (12.1.3.0.0), OEM 12c, Oracle Database, OEL Linux,
# Windows server 2012 R12.
# Responsibilities:
# ✓ Installation and configuration for WebLogic environment on OEL operating system level.
# Balajee
# Cell: +91-7901533189
# Email: nagabalajifmw@gmail.com
# ✓ Handling Out of Memory server hang startup issues.
# ✓ Generating custom Authentication Providers, Identity Asserters and other providers like
# Authorization, Auditing, and Credential Mapping etc.
# ✓ Cluster Configuration – Single Cluster, Multiple Clusters.
# ✓ Worked on Configurations, SSL, and Key stores.
# ✓ Configuring Apache web servers as proxy servers.
# ✓ Configuration of Node Manager and Enrolling the Domains
# ✓ Prepared shell script for managed servers space utilization.
# ✓ shell scripts for node manager and SOA managed servers.
# ✓ Oracle apps adapter configuration for SOA environment and OSB environment.
# ✓ Managed all Application-Server related activities such as deployments, monitoring and tuning
# in the Development, QA and Production Environments.
# ✓ Responsible of load testing of the application.
# ✓ Involved in the installation of WebLogic Server.
# ✓ Configuring cluster for Load Balancing and for High Availability.
# ✓ Creation of Connection Pools in WebLogic Server, handling deployments an application in
# Server.
# ✓ Able to handle Change Control Requests, handle Support Central Requests.
# ✓ Handling out of Memory issue.
# ✓ WebLogic Administration act as an effective interface between client and vendor responsible of
# verifying Logs, Application Log, WebLogic Log, Database Logs.
# ✓ Troubleshooting an application in Server and JVM tuning.
# ✓ Raised the BEA Cases.
# ✓ Managing Authentication, Authorization, Access control for security issues and virtual hosts
# activities.
# ✓ Analyzing of java exceptions, which are generated during the usage of application.
# ✓ Prepared the Shell scripts for all the Unix servers space utilization.
#
# ==================================================
#
# --- Text from Naukri_VishnuA[2y_0m] (1).pdf ---
# VISHNU A
# Software Engineer
# No.3Sarojini2ndStreet
# PallavaramP.O.
# Chennai-600043
# +917904644939
# vishnu13792@gmail.com
# OBJECTIVE
# ASoftwareDeveloperwithentry-levelexperiencespecializinginuserinterfacedesign,application
# development,datasecurity,andcontinuousimprovement.Adeptatidentifyingopportunitiesto
# enhancetheuserexperienceanddevelopnewfeaturestoimproveappfunctionality.
# EXPERIENCE( 1.8 Yrs)
# Ciranta IT Service PVT. LTD, Chennai
# SoftwareDeveloper
# OCT2021-JUN2023
# PROJECTS
# AfricanHRMS
# ● ProjectwasOdooimplementationforHRMSservices
# ● WorkedasdeveloperfortheimplementationandcustomizationofOdoo
# AssetManagementmodule
# ● IntegrationofMailServicetotheexistingservice.
# ● ImplementedReportgenerationofexistingmodules.
# DynamicVoiceData
# ● TheprojectwasOdoo'simplementationofERPSalesandPurchase
# ● WorkedasdeveloperimplementationofCRvalidations
# ● ImplementedReportgenerationofexistingmodules.
# ● LargeVolumeofdatamigrationfrompreviousservicestothenewone.
# ● DBcleaningisdoneforthepurposeofaBettersystem.
# BookwedGo
# ● TheprojectwasaDjangoapplicationfortheAuditoriumBookingservice
# ● WorkedasabackenddevelopertoimplementandmodifyRESTAPIservice
# ● DonemanualtestingonexistingandnewAPIendpoints.
# EDUCATION
# Gurunanak college, Chennai
# B.Sc.IT
# JUN2018-MAR2021
# SuccessfullycompletedthreeyeardegreecourseinITwith7.8CGPA
# Jaigopal Garodia National HSS, Chennai
# +2
# JUN2016-MAR2018
# SuccessfullycompletedhighersecondaryeducationinComputerSciencewith65
# percentage
# Jaigopal Garodia National HSS, Chennai
# SSLC
# JUN2015-MAR2016
# Successfullycompletedsecondaryeducationwith80.3percentage
# COURSES
# PythonandOracleSQLCourse
# BesantTechnologies,Chennai
# FEB2024-AUG2024
# ● LearnedadvancedPythonfeatures.
# ● LearnedDjangoFrameworkforfull-stackapplicationimplementationwith
# Mysql.
# ● LearnedBasicsofSQLwithOracle
# ● LearnedPythonLibrariesasPandas
# ● LearnedWebScraping
# TECHNICAL SKILLS
# Coding -Python
# FrontendTechnology -HTML,CSS,Javascript
# Frameworks -Django,Flask,Odoo,DjangoORM
# Libraries -Pandas
# DBMS -Oracle,Mysql,Postgresql,SQLite
# Testing -Postman
# IDE -PycharmandVSCode
# ProjectManagementTool -Orangescrum
# RepositoryManagementTool -Git,GitLab
#
# ==================================================
#
# --- Text from Naukri_VishnuA[2y_0m].pdf ---
# VISHNU A
# Software Engineer
# No.3Sarojini2ndStreet
# PallavaramP.O.
# Chennai-600043
# +917904644939
# vishnu13792@gmail.com
# OBJECTIVE
# ASoftwareDeveloperwithentry-levelexperiencespecializinginuserinterfacedesign,application
# development,datasecurity,andcontinuousimprovement.Adeptatidentifyingopportunitiesto
# enhancetheuserexperienceanddevelopnewfeaturestoimproveappfunctionality.
# EXPERIENCE( 1.8 Yrs)
# Ciranta IT Service PVT. LTD, Chennai
# SoftwareDeveloper
# OCT2021-JUN2023
# PROJECTS
# AfricanHRMS
# ● ProjectwasOdooimplementationforHRMSservices
# ● WorkedasdeveloperfortheimplementationandcustomizationofOdoo
# AssetManagementmodule
# ● IntegrationofMailServicetotheexistingservice.
# ● ImplementedReportgenerationofexistingmodules.
# DynamicVoiceData
# ● TheprojectwasOdoo'simplementationofERPSalesandPurchase
# ● WorkedasdeveloperimplementationofCRvalidations
# ● ImplementedReportgenerationofexistingmodules.
# ● LargeVolumeofdatamigrationfrompreviousservicestothenewone.
# ● DBcleaningisdoneforthepurposeofaBettersystem.
# BookwedGo
# ● TheprojectwasaDjangoapplicationfortheAuditoriumBookingservice
# ● WorkedasabackenddevelopertoimplementandmodifyRESTAPIservice
# ● DonemanualtestingonexistingandnewAPIendpoints.
# EDUCATION
# Gurunanak college, Chennai
# B.Sc.IT
# JUN2018-MAR2021
# SuccessfullycompletedthreeyeardegreecourseinITwith7.8CGPA
# Jaigopal Garodia National HSS, Chennai
# +2
# JUN2016-MAR2018
# SuccessfullycompletedhighersecondaryeducationinComputerSciencewith65
# percentage
# Jaigopal Garodia National HSS, Chennai
# SSLC
# JUN2015-MAR2016
# Successfullycompletedsecondaryeducationwith80.3percentage
# COURSES
# PythonandOracleSQLCourse
# BesantTechnologies,Chennai
# FEB2024-AUG2024
# ● LearnedadvancedPythonfeatures.
# ● LearnedDjangoFrameworkforfull-stackapplicationimplementationwith
# Mysql.
# ● LearnedBasicsofSQLwithOracle
# ● LearnedPythonLibrariesasPandas
# ● LearnedWebScraping
# TECHNICAL SKILLS
# Coding -Python
# FrontendTechnology -HTML,CSS,Javascript
# Frameworks -Django,Flask,Odoo,DjangoORM
# Libraries -Pandas
# DBMS -Oracle,Mysql,Postgresql,SQLite
# Testing -Postman
# IDE -PycharmandVSCode
# ProjectManagementTool -Orangescrum
# RepositoryManagementTool -Git,GitLab
#
# ==================================================

# %%
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate 
from langchain_core.pydantic_v1 import BaseModel, Field 
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
 
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    api_key="AIzaSyC_1emKcfen2n5ZS-cjOTT37najYpBWmco",
)
 
llm.invoke("wow")
# Out:
# AIMessage(content='Wow indeed!  Is there anything I can help you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-bf7b4c6e-bc6e-4caa-851c-439222d1786d-0', usage_metadata={'input_tokens': 1, 'output_tokens': 14, 'total_tokens': 15, 'input_token_details': {'cache_read': 0}})

# %%
 
class Resume(BaseModel):
    name: str = Field(description="name from resume")
    phone: str = Field(description="phone number from resume")
    email: str = Field(description="email from resume ")
    skill: str=Field(description="skill from resume")

# %%
resume_query = pdf_texts
 

parser = JsonOutputParser(pydantic_object=Resume)
 
prompt = PromptTemplate(
    template="extract name,phone,email,education,projects,technical_skills and certifications from the given text resume.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)
 
chain = prompt | llm | parser
 
details = chain.invoke({"query": resume_query})
details
# Out:
# [{'name': 'AJITHA V',
#   'phone': '7010853283',
#   'email': 'ajithavr99@gmail.com',
#   'skill': 'Python'},
#  {'name': 'ANISRAJ.G',
#   'phone': '8526113766',
#   'email': 'anisraj103@gmail.com',
#   'skill': 'Python'},
#  {'name': 'ANUSHA B',
#   'phone': '+91 9677495546',
#   'email': 'anushabt00@gmail.com',
#   'skill': 'Full-cycle recruitment'},
#  {'name': 'Arul Mozhi Varman',
#   'phone': '(+91) 8508932314',
#   'email': 'arulmozhivarman861@gmail.com',
#   'skill': 'Linux System Administrator'},
#  {'name': 'ASHWINI NATESAN',
#   'phone': '+91 90942 50130',
#   'email': 'ashwininatesan1317@gmail.com',
#   'skill': 'Project Manager'},
#  {'name': 'ATHIRA U',
#   'phone': '+91-9746226373',
#   'email': 'athirauday05@gmail.com',
#   'skill': 'Certified Scrum Master'},
#  {'name': 'Azarudeen A',
#   'phone': '9360047121',
#   'email': 'azarudeensuban@gmail.com',
#   'skill': 'Web Developer'},
#  {'name': 'Balajee',
#   'phone': '+91-7901533189',
#   'email': 'nagabalajifmw@gmail.com',
#   'skill': 'Platform administration Consultant'},
#  {'name': 'VISHNU A',
#   'phone': '+917904644939',
#   'email': 'vishnu13792@gmail.com',
#   'skill': 'Software Engineer'}]

# %%
import pandas as pd
 
df = pd.DataFrame(details)
print("Simple Table:")
print(df)
# Out:
# Simple Table:
#                 name             phone                         email  \
# 0           AJITHA V        7010853283          ajithavr99@gmail.com
# 1          ANISRAJ.G        8526113766          anisraj103@gmail.com
# 2           ANUSHA B    +91 9677495546          anushabt00@gmail.com
# 3  Arul Mozhi Varman  (+91) 8508932314  arulmozhivarman861@gmail.com
# 4    ASHWINI NATESAN   +91 90942 50130  ashwininatesan1317@gmail.com
# 5           ATHIRA U    +91-9746226373        athirauday05@gmail.com
# 6        Azarudeen A        9360047121      azarudeensuban@gmail.com
# 7            Balajee    +91-7901533189       nagabalajifmw@gmail.com
# 8           VISHNU A     +917904644939         vishnu13792@gmail.com
#
#                                 skill
# 0                              Python
# 1                              Python
# 2              Full-cycle recruitment
# 3          Linux System Administrator
# 4                     Project Manager
# 5              Certified Scrum Master
# 6                       Web Developer
# 7  Platform administration Consultant
# 8                   Software Engineer

# %%
df.to_csv("sample_details.csv", index=False)
